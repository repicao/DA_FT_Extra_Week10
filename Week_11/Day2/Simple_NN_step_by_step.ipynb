# %%
# Import PyTorch and NumPy
import torch
from torch import optim
import numpy as np
list_1 = [1, 2, 3, 4]

# Create a tensor from list_a
tensor_a = torch.tensor(list_1)

# Display the tensor device
print(tensor_a.device)

# Display the tensor data type
print(tensor_a.dtype)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 4
#       2 import torch
#       3 from torch import optim
# ----> 4 from torch.optim import criterion
#       5 import numpy as np
#       6 list_1 = [1, 2, 3, 4]
#
# ImportError: cannot import name 'criterion' from 'torch.optim' (/Users/aleksanderdasilvaboski/anaconda3/lib/python3.11/site-packages/torch/optim/__init__.py)

# %%
# Create two numpy arrays from two lists
list_1 = [1, 2, 3, 4]
list_2 = [5, 6, 7, 8]

arr1 = np.array(list_1)
arr2 = np.array(list_2)

# %%
# Create two tensors from the arrays
tensor_a = torch.tensor(arr1)
tensor_b = torch.tensor(arr2)

# Subtract tensor_b from tensor_a 
tensor_c = tensor_a - tensor_b

# Multiply each element of tensor_a with each element of tensor_b
tensor_d = tensor_a * tensor_b

# Add tensor_c to tensor_d
tensor_e = tensor_c + tensor_d
print(tensor_e)
# Out:
# tensor([ 1,  8, 17, 28])

# %%
import torch
import torch.nn as nn

input_tensor = torch.Tensor([[2, 3, 6, 7, 9, 3, 2, 1]])

# Implement a small neural network with exactly two linear layers
model = nn.Sequential(nn.Linear(8, 4),
                      nn.Linear(4, 1)
                     )

output = model(input_tensor)
print(output)
# Out:
# tensor([[-0.8434]], grad_fn=<AddmmBackward0>)

# %%
input_tensor = torch.tensor([[0.8]])

# Create a sigmoid function and apply it on input_tensor
sigmoid = nn.Sigmoid()
probability = sigmoid(input_tensor)
print(probability)
# Out:
# tensor([[0.6900]])

# %%
# Create the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.001)

loss = criterion(pred, target)
loss.backward()

# Update the model's parameters using the optimizer
optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 # Create the optimizer
#       2 optimizer = optim.SGD(model.parameters(), lr=0.001)
# ----> 4 loss = criterion(pred, target)
#       5 loss.backward()
#       7 # Update the model's parameters using the optimizer
#
# NameError: name 'criterion' is not defined
